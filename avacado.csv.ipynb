# %%
import pandas as pd
import numpy as np
avo=pd.read_csv('avo.csv')

# %%
avo.tail()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 1512          10  16-10-2016          1.39     190846.01  57529.11  56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87  52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75  52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79  53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41  54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#       year     region
# ...

# %%
avo.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avo.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
avo=avo.drop(['Date','Total Bags'],axis=1)

# %%
avo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   int64
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Small Bags    1517 non-null   float64
#  7   Large Bags    1517 non-null   float64
#  8   XLarge Bags   1517 non-null   float64
#  9   type          1517 non-null   object
#  10  year          1517 non-null   int64
#  11  region        1517 non-null   object
# dtypes: float64(8), int64(2), object(2)
# memory usage: 142.3+ KB

# %%
avo.dtypes
# Out:
# Unnamed: 0        int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
avo['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'Columbus', 'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids',
#        'GreatLakes', 'HarrisburgScranton', 'HartfordSpringfield',
#        'Houston', 'Indianapolis', 'Jacksonville', 'LasVegas',
#        'LosAngeles', 'Louisville', 'MiamiFtLauderdale', 'Midsouth',
#        'Nashville', 'NewYork', 'Northeast', 'NorthernNewEngland',
#        'Orlando', 'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains',
#        'Portland', 'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
avo1=avo.drop(['year','Unnamed: 0'],axis=1)

# %%
avo1.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Small Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8603.62
# 1          1.35      54876.98   674.28   44638.81   58.33     9408.07
# 2          0.93     118220.22   794.70  109149.67  130.50     8042.21
# 3          1.08      78992.15  1132.00   71976.41   72.58     5677.40
# 4          1.28      51039.60   941.48   43838.39   75.78     5986.26
#
#    Large Bags  XLarge Bags          type  region
# 0       93.25          0.0  conventional  Albany
# 1       97.49          0.0  conventional  Albany
# 2      103.14          0.0  conventional  Albany
# 3      133.76          0.0  conventional  Albany
# 4      197.69          0.0  conventional  Albany

# %%
avo1.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Small Bags    Large Bags    XLarge Bags
# count  1.517000e+03  1.517000e+03    1517.000000
# mean   2.487736e+05  4.264205e+04    2181.771074
# std    6.474765e+05  1.182157e+05    7455.712144
# min    3.311770e+03  0.000000e+00       0.000000
# ...

# %%
avo1.type.unique()
# Out:
# array(['conventional'], dtype=object)

# %%
avo=avo1.drop(['type'],axis=1)

# %%
avo1
# Out:
#       AveragePrice  Total Volume      4046       4225      4770  Small Bags  \
# 0             1.33      64236.62   1036.74   54454.85     48.16     8603.62
# 1             1.35      54876.98    674.28   44638.81     58.33     9408.07
# 2             0.93     118220.22    794.70  109149.67    130.50     8042.21
# 3             1.08      78992.15   1132.00   71976.41     72.58     5677.40
# 4             1.28      51039.60    941.48   43838.39     75.78     5986.26
# ...            ...           ...       ...        ...       ...         ...
# 1512          1.39     190846.01  57529.11   56366.66  17531.78    48823.53
# 1513          1.51     178235.75  43325.87   52189.61  19419.57    54704.14
# 1514          1.48     178410.82  46364.75   52893.38  16736.92    53332.61
# 1515          1.47     189131.52  54110.79   53593.58  17495.42    55653.47
# 1516          1.43     182978.30  43116.41   54193.42  16563.91    57456.21
#
#       Large Bags  XLarge Bags          type     region
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(avo.isnull())
plt.show()

# %%
avo=avo.corr()
avo
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
#
#               Small Bags  Large Bags  XLarge Bags
# AveragePrice   -0.097682   -0.177480    -0.048284
# Total Volume    0.960642    0.910226     0.521717
# 4046            0.922278    0.884229     0.474063
# 4225            0.943988    0.900496     0.504718
# 4770            0.923607    0.840523     0.646053
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(avo,annot=True,cmap='winter')

# %%
plt.figure(figsize=(100,50))
avo['AveragePrice'].plot.bar()
plt.show()

# %%
avo['Small Bags'].plot.hist()
plt.title('Histogram of Small Bags column')
plt.show()

# %%
avo['Large Bags'].plot.hist(bins=10)
plt.title('Histogram of Large Bags column')
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(avo['Small Bags'])

# %%
plt.figure(figsize=(10,10))
sns.set(style='white')
plt.scatter(avo['AveragePrice'],avo['Total Volume'])
plt.xlabel('AveragePrice')
# Out:
# Text(0.5, 0, 'AveragePrice')

# %%
plt.figure(figsize=(12,16))
sns.regplot(x='Large Bags',y='AveragePrice',data=avo,fit_reg=False)
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.regplot(x='Total Volume',y='AveragePrice',data=avo,fit_reg=False)
plt.show()

# %%
avo1.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# region           object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() 
avo1['region']=le.fit_transform(avo1['region'])

# %%
avo=avo1.drop(['type'],axis=1)

# %%
collist=avo.columns.values
ncol=15
nrow=10

# %%
plt.figure(figsize=(50,20))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(avo[collist[i]],color='black')
    plt.tight_layout()

# %%
avo.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# region          0.288146
# dtype: float64

# %%
for col in avo.columns:
    if avo[col].skew()>0.55:
        avo[col]=np.log1p(avo[col])

# %%
avo.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# region          0.288146
# dtype: float64

# %%
avo.shape
# Out:
# (1517, 9)

# %%
avo['4046'].plot.box()

# %%
avo['4225'].plot.box()

# %%
avo.plot(kind='box',subplots=True,layout=(2,6))
# Out:
# AveragePrice       AxesSubplot(0.125,0.536818;0.110714x0.343182)
# Total Volume    AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# 4046            AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# 4225            AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# 4770            AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# Small Bags      AxesSubplot(0.789286,0.536818;0.110714x0.343182)
# Large Bags            AxesSubplot(0.125,0.125;0.110714x0.343182)
# XLarge Bags        AxesSubplot(0.257857,0.125;0.110714x0.343182)
# region             AxesSubplot(0.390714,0.125;0.110714x0.343182)
# dtype: object

# %%
from scipy.stats import zscore
z_score=abs(zscore(avo))
print(avo.shape)
avo=avo.loc[(z_score<2).all(axis=1)]
print(avo.shape)
# Out:
# (1517, 9)
# (1183, 9)

# %%
df_x=avo.drop(columns=['AveragePrice'])

# %%
y=pd.DataFrame(avo['AveragePrice'])

# %%
df_x.head()
# Out:
#    Total Volume      4046       4225      4770  Small Bags  Large Bags  \
# 0     11.070344  6.944801  10.905146  3.895080    9.060055    4.545951
# 2     11.680313  6.679222  11.600485  4.879007    8.992584    4.645736
# 3     11.277116  7.032624  11.184108  4.298373    8.644425    4.903495
# 4     10.840377  6.848515  10.688288  4.340944    8.697389    5.291746
# 5     10.932764  7.077726  10.780393  3.797958    8.788360    4.855462
#
#    XLarge Bags  region
# 0          0.0       0
# 2          0.0       0
# 3          0.0       0
# 4          0.0       0
# 5          0.0       0

# %%
y.head()
# Out:
#    AveragePrice
# 0          1.33
# 2          0.93
# 3          1.08
# 4          1.28
# 5          1.26

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.shape
# Out:
# (1183, 8)

# %%
y.shape
# Out:
# (1183, 1)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
model=Ridge()
grid=GridSearchCV(estimator=model,param_grid=alphavalue,cv=5)
grid.fit(x,y)
print(grid)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 0.04328501962602864
# {'alpha': 1}

# %%
from sklearn import svm
svr=svm.SVR()
parameters={'kernel':['linear','rbf','poly'],'C':[1.0]}
gd=GridSearchCV(svr,parameters)
gd.fit(x,y)
sorted(gd.cv_results_.keys())
print(gd.best_params_)
# Out:
# {'C': 1.0, 'kernel': 'linear'}

# %%
max_r_score=0
for r_state in range (40,1400):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
    regr=DecisionTreeRegressor()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r_scr=r2_score(y_test,y_pred)
    if r_scr>max_r_score:
        max_r_score=r_scr
        final_r_state=r_state
print('max r2 score corresponding to',final_r_state,'is',max_r_score)
# Out:
# max r2 score corresponding to 564 is 0.7634249191168953

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(kernel='linear'),Lasso(),Ridge(alpha=0),ElasticNet(),]
for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=564,test_size=.20)
    m.fit(x_train,y_train)
    print('score of',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Error:')
    print('Mean Absolute Error:',mean_absolute_error(y_test,predm))
    print('Mean Squared Error:',mean_squared_error(y_test,predm))
    print('r2_score',r2_score(y_test,predm))
    print('***************************************************************************************************')
    print('\n')
# Out:
# score of LinearRegression() is: 0.34653324179635425
# Error:
# Mean Absolute Error: 0.09982531070945379
# Mean Squared Error: 0.015591158791424562
# r2_score 0.3934010980793873
# ***************************************************************************************************
#
#
# score of DecisionTreeRegressor() is: 1.0
# Error:
# Mean Absolute Error: 0.0640084388185654
# Mean Squared Error: 0.008205485232067511
# r2_score 0.680752508643832
# ***************************************************************************************************
#
#
# score of KNeighborsRegressor() is: 0.8301783805750935
# Error:
# Mean Absolute Error: 0.055628691983122355
# Mean Squared Error: 0.005363409282700423
# r2_score 0.7913280067914932
# ***************************************************************************************************
#
#
# score of SVR(kernel='linear') is: 0.3441513498486879
# Error:
# Mean Absolute Error: 0.09888774243549396
# Mean Squared Error: 0.015290301871182705
# ...

# %%
from sklearn.model_selection import cross_val_score
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(kernel='poly'),Lasso(),Ridge(alpha=1),ElasticNet(),RandomForestRegressor(),AdaBoostRegressor()]
for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='r2')
    print('Score of',m,'is:',score)
    print('Mean score:',score.mean())
    print('Standard deviation:',score.std())
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression() is: [-0.51072438  0.31622089  0.05393446  0.12749471  0.20851041]
# Mean score: 0.03908721923766771
# Standard deviation: 0.28838737974472617
# *******************************************************************************************************
#
#
# Score of DecisionTreeRegressor() is: [-0.94322145 -0.16288732 -0.92377584 -0.57236405 -0.32126687]
# Mean score: -0.5847031056654904
# Standard deviation: 0.31336406140347195
# *******************************************************************************************************
#
#
# Score of KNeighborsRegressor() is: [-0.16080139  0.29671498 -1.04541967 -1.01509383  0.42228069]
# Mean score: -0.3004638434132193
# Standard deviation: 0.626760401423982
# *******************************************************************************************************
#
#
# Score of SVR(kernel='poly') is: [-3.31967633  0.14085934 -0.79390183 -0.16573393 -1.11557192]
# Mean score: -1.0508049331357352
# ...

# %%
import joblib
joblib.dump(KNeighborsRegressor,'avacado.pkl')
# Out:
# ['avacado.pkl']
